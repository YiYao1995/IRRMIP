# %%
# %matplotlib inline       
import scipy.io as scio
import matplotlib.pyplot as plt
import matplotlib as mpl
import cartopy.feature as cfeature
import cartopy.crs as ccrs
import netCDF4 as nc
import numpy as np
from Load_data import Data_from_nc
import xarray as xr
import math
import gc
 #Data from /theia/scratch/databases/climate/cesm/inputdata/lnd/clm2/surfdata_map/IRRMIP....m
def get_data_from_nc(file, variable):
    file_obj = nc.Dataset(file)
    data = file_obj.variables[variable]
    var_data = np.array(data)
    var_data = var_data[:, 29:, :]
    var_data[var_data > 1000000] = np.nan
    var_data = np.squeeze(var_data)
    return var_data

def get_data_from_mat(file, variable):
    var_dict = scio.loadmat(file)
    var = var_dict[variable]
    var = var[:, 29:] 
    return var

def get_data_from_mat_1(file, variable):
    var_dict = scio.loadmat(file)
    var = var_dict[variable]
    return var

def get_data_from_mat_for_calcu(file, variable):
    var_dict = scio.loadmat(file)
    var = var_dict[variable]
    var = var[:, 29:]
    return var.T


AREA = get_data_from_mat('/dodrio/scratch/projects/2022_200/project_output/cesm/yi_yao_IRRMIP/input_data/AREA.mat', 'AREA') # Area for CLM_data

def calcu_global_IWW(str, AREA, var):
    IWW_1901_2014 = get_data_from_nc(str, var)
    IWW_globe_1901_2014 = IWW_1901_2014 * (AREA.T) / 1000000
    IWW_globe_1901_2014 = np.nansum(IWW_globe_1901_2014, axis=1)
    IWW_globe_1901_2014 = np.nansum(IWW_globe_1901_2014, axis=1)
    return IWW_globe_1901_2014

def calcu_global_IWW_region(str, AREA,region_id, var):
    IWW_1901_2014 = get_data_from_nc(str, var)
    IWW_globe_1901_2014 = IWW_1901_2014 * (AREA.T) / 1000000
    IWW_globe_1901_2014[:, ar6_region!=region_id] = np.nan
    IWW_globe_1901_2014 = np.nansum(IWW_globe_1901_2014, axis=1)
    IWW_globe_1901_2014 = np.nansum(IWW_globe_1901_2014, axis=1)
    return IWW_globe_1901_2014

def calcu_global_IWW_region_no_str(IWW_1901_2014, AREA,region_id, var):
    IWW_globe_1901_2014 = IWW_1901_2014 * (AREA.T) / 1000000
    IWW_globe_1901_2014[:, ar6_region!=region_id] = np.nan
    IWW_globe_1901_2014 = np.nansum(IWW_globe_1901_2014, axis=1)
    IWW_globe_1901_2014 = np.nansum(IWW_globe_1901_2014, axis=1)
    return IWW_globe_1901_2014

def calcu_global_AREA(global_irri_land_map):
    global_irri_land_map = np.nansum(global_irri_land_map, axis=1)
    global_irri_land = np.nansum(global_irri_land_map, axis=1)
    return global_irri_land

def calcu_global_AREA_region(global_irri_land_map, region_id):
    global_irri_land_map[:, ar6_region!=region_id] = np.nan
    global_irri_land_map = np.nansum(global_irri_land_map, axis=1)
    global_irri_land = np.nansum(global_irri_land_map, axis=1)
    return global_irri_land

ar6_region = get_data_from_mat_for_calcu('/dodrio/scratch/projects/2022_200/project_output/cesm/yi_yao_IRRMIP/ar6_region.mat','ar6_region')

irr_diff = get_data_from_mat_for_calcu('/dodrio/scratch/projects/2022_200/project_output/cesm/yi_yao_IRRMIP/irr_diff_out.mat', 'irr_diff_out')


data_surface = Data_from_nc('/dodrio/scratch/projects/2022_200/project_output/cesm/yi_yao_IRRMIP/surfdata_irrigation_method.nc')   #load the data
data_irrigation_method = data_surface.load_variable('irrigation_method')
data_lon = data_surface.load_variable('LONGXY')
data_lon = data_lon[0,:]
data_lat = data_surface.load_variable('LATIXY')
data_lat = data_lat[29:,0]
data_lat = data_lat[:]

# %%
globe_irr_land_IRR = get_data_from_mat_1('/dodrio/scratch/projects/2022_200/project_output/cesm/yi_yao_IRRMIP/input_data/global_irri_land.mat', 'global_irri_land')
globe_irr_land_NOI = get_data_from_mat_1('/dodrio/scratch/projects/2022_200/project_output/cesm/yi_yao_IRRMIP/input_data/global_irri_land_noirr.mat', 'global_irri_land')

global_irri_land_map = get_data_from_mat_1('/dodrio/scratch/projects/2022_200/project_output/cesm/yi_yao_IRRMIP/input_data/global_irri_land_map.mat', 'global_irri_land_map')

global_irri_land_map = global_irri_land_map.transpose(2,1,0)

global_irri_land_map = global_irri_land_map[:,29:,:]

global_irri_land = calcu_global_AREA(global_irri_land_map)

global_irri_land_WNA = calcu_global_AREA_region(global_irri_land_map, 4)

global_irri_land_map = get_data_from_mat_1('/dodrio/scratch/projects/2022_200/project_output/cesm/yi_yao_IRRMIP/input_data/global_irri_land_map.mat', 'global_irri_land_map')

global_irri_land_map = global_irri_land_map.transpose(2,1,0)

global_irri_land_map = global_irri_land_map[:,29:,:]

global_irri_land = calcu_global_AREA(global_irri_land_map)

global_irri_land_CNA = calcu_global_AREA_region(global_irri_land_map, 5)

global_irri_land_map = get_data_from_mat_1('/dodrio/scratch/projects/2022_200/project_output/cesm/yi_yao_IRRMIP/input_data/global_irri_land_map.mat', 'global_irri_land_map')

global_irri_land_map = global_irri_land_map.transpose(2,1,0)

global_irri_land_map = global_irri_land_map[:,29:,:]

global_irri_land = calcu_global_AREA(global_irri_land_map)

global_irri_land_NCA = calcu_global_AREA_region(global_irri_land_map, 7)

global_irri_land_map = get_data_from_mat_1('/dodrio/scratch/projects/2022_200/project_output/cesm/yi_yao_IRRMIP/input_data/global_irri_land_map.mat', 'global_irri_land_map')

global_irri_land_map = global_irri_land_map.transpose(2,1,0)

global_irri_land_map = global_irri_land_map[:,29:,:]

global_irri_land = calcu_global_AREA(global_irri_land_map)

global_irri_land_MED = calcu_global_AREA_region(global_irri_land_map, 20)

global_irri_land_map = get_data_from_mat_1('/dodrio/scratch/projects/2022_200/project_output/cesm/yi_yao_IRRMIP/input_data/global_irri_land_map.mat', 'global_irri_land_map')

global_irri_land_map = global_irri_land_map.transpose(2,1,0)

global_irri_land_map = global_irri_land_map[:,29:,:]

global_irri_land = calcu_global_AREA(global_irri_land_map)

global_irri_land_WCA = calcu_global_AREA_region(global_irri_land_map, 33)

global_irri_land_map = get_data_from_mat_1('/dodrio/scratch/projects/2022_200/project_output/cesm/yi_yao_IRRMIP/input_data/global_irri_land_map.mat', 'global_irri_land_map')

global_irri_land_map = global_irri_land_map.transpose(2,1,0)

global_irri_land_map = global_irri_land_map[:,29:,:]

global_irri_land = calcu_global_AREA(global_irri_land_map)

global_irri_land_EAS = calcu_global_AREA_region(global_irri_land_map, 36)

global_irri_land_map = get_data_from_mat_1('/dodrio/scratch/projects/2022_200/project_output/cesm/yi_yao_IRRMIP/input_data/global_irri_land_map.mat', 'global_irri_land_map')

global_irri_land_map = global_irri_land_map.transpose(2,1,0)

global_irri_land_map = global_irri_land_map[:,29:,:]

global_irri_land = calcu_global_AREA(global_irri_land_map)

global_irri_land_SAS = calcu_global_AREA_region(global_irri_land_map, 38)

global_irri_land_map = get_data_from_mat_1('/dodrio/scratch/projects/2022_200/project_output/cesm/yi_yao_IRRMIP/input_data/global_irri_land_map.mat', 'global_irri_land_map')

global_irri_land_map = global_irri_land_map.transpose(2,1,0)

global_irri_land_map = global_irri_land_map[:,29:,:]

global_irri_land = calcu_global_AREA(global_irri_land_map)

global_irri_land_SEA = calcu_global_AREA_region(global_irri_land_map, 39)

global_irri_land_map = get_data_from_mat_1('/dodrio/scratch/projects/2022_200/project_output/cesm/yi_yao_IRRMIP/input_data/global_irri_land_map.mat', 'global_irri_land_map')

global_irri_land_map = global_irri_land_map.transpose(2,1,0)

global_irri_land_map = global_irri_land_map[:,29:,:]

global_irri_land = calcu_global_AREA(global_irri_land_map)

# %%
str_IWW_CESM2 = '/dodrio/scratch/projects/2022_200/project_output/cesm/yi_yao_IRRMIP/after_process/CESM2/QIRRIG/CESM2_IRR_YEARLYQIRRIG_timmean_1901_2014.nc'
IWW_IRR_1901_2014_CESM2 = calcu_global_IWW(str_IWW_CESM2, AREA, 'QIRRIG')
str_IWW_CESM2_NOI = '/dodrio/scratch/projects/2022_200/project_output/cesm/yi_yao_IRRMIP/after_process/CESM2/QIRRIG/CESM2_NOI_YEARLYQIRRIG_timmean_1901_2014.nc'
IWW_NOI_1901_2014_CESM2 = calcu_global_IWW(str_IWW_CESM2_NOI, AREA, 'QIRRIG')

str_IWW_CESM2_IRR01 = '/dodrio/scratch/projects/2022_200/project_output/cesm/yi_yao_IRRMIP/after_process/CESM2/QIRRIG/CESM2_IRR01_YEARLYQIRRIG_timmean_1901_2014.nc'
IWW_IRR_1901_2014_CESM2_IRR01 = calcu_global_IWW(str_IWW_CESM2_IRR01, AREA, 'QIRRIG')
str_IWW_CESM2_NOI01 = '/dodrio/scratch/projects/2022_200/project_output/cesm/yi_yao_IRRMIP/after_process/CESM2/QIRRIG/CESM2_NOI01_YEARLYQIRRIG_timmean_1901_2014.nc'
IWW_NOI_1901_2014_CESM2_IRR01 = calcu_global_IWW(str_IWW_CESM2_NOI01, AREA, 'QIRRIG')

str_IWW_CESM2_IRR02 = '/dodrio/scratch/projects/2022_200/project_output/cesm/yi_yao_IRRMIP/after_process/CESM2/QIRRIG/CESM2_IRR02_YEARLYQIRRIG_timmean_1901_2014.nc'
IWW_IRR_1901_2014_CESM2_IRR02 = calcu_global_IWW(str_IWW_CESM2_IRR02, AREA, 'QIRRIG')
str_IWW_CESM2_NOI02 = '/dodrio/scratch/projects/2022_200/project_output/cesm/yi_yao_IRRMIP/after_process/CESM2/QIRRIG/CESM2_NOI02_YEARLYQIRRIG_timmean_1901_2014.nc'
IWW_NOI_1901_2014_CESM2_IRR02 = calcu_global_IWW(str_IWW_CESM2_NOI02, AREA, 'QIRRIG')

str_IWW_CESM2_IRR03 = '/dodrio/scratch/projects/2022_200/project_output/cesm/yi_yao_IRRMIP/after_process/CESM2/QIRRIG/CESM2_IRR03_YEARLYQIRRIG_timmean_1901_2014.nc'
IWW_IRR_1901_2014_CESM2_IRR03 = calcu_global_IWW(str_IWW_CESM2_IRR03, AREA, 'QIRRIG')
str_IWW_CESM2_NOI03 = '/dodrio/scratch/projects/2022_200/project_output/cesm/yi_yao_IRRMIP/after_process/CESM2/QIRRIG/CESM2_NOI03_YEARLYQIRRIG_timmean_1901_2014.nc'
IWW_NOI_1901_2014_CESM2_IRR03 = calcu_global_IWW(str_IWW_CESM2_NOI03, AREA, 'QIRRIG')

IWW_IRR_1901_2014_CESM2 = (IWW_IRR_1901_2014_CESM2_IRR01 + IWW_IRR_1901_2014_CESM2_IRR02 + IWW_IRR_1901_2014_CESM2_IRR03)/3
IWW_NOI_1901_2014_CESM2 = (IWW_NOI_1901_2014_CESM2_IRR01 + IWW_NOI_1901_2014_CESM2_IRR02 + IWW_NOI_1901_2014_CESM2_IRR03)/3


str_IWW_CESM2_gw = '/dodrio/scratch/projects/2022_200/project_output/cesm/yi_yao_IRRMIP/after_process/CESM2_gw/QIRRIG/CESM2_gw_IRR_YEARLYQIRRIG_timmean_1901_2014.nc'
IWW_IRR_1901_2014_CESM2_gw = calcu_global_IWW(str_IWW_CESM2_gw, AREA, 'QIRRIG')
str_IWW_CESM2_gw_NOI = '/dodrio/scratch/projects/2022_200/project_output/cesm/yi_yao_IRRMIP/after_process/CESM2_gw/QIRRIG/CESM2_gw_NOI_YEARLYQIRRIG_timmean_1901_2014.nc'
IWW_NOI_1901_2014_CESM2_gw = calcu_global_IWW(str_IWW_CESM2_gw_NOI, AREA, 'QIRRIG')

str_IWW_CESM2_gw_IRR01 = '/dodrio/scratch/projects/2022_200/project_output/cesm/yi_yao_IRRMIP/after_process/CESM2_gw/QIRRIG/CESM2_gw_IRR01_YEARLYQIRRIG_timmean_1901_2014.nc'
IWW_IRR_1901_2014_CESM2_gw_IRR01 = calcu_global_IWW(str_IWW_CESM2_gw_IRR01, AREA, 'QIRRIG')
str_IWW_CESM2_gw_NOI01 = '/dodrio/scratch/projects/2022_200/project_output/cesm/yi_yao_IRRMIP/after_process/CESM2_gw/QIRRIG/CESM2_gw_NOI01_YEARLYQIRRIG_timmean_1901_2014.nc'
IWW_NOI_1901_2014_CESM2_gw_IRR01 = calcu_global_IWW(str_IWW_CESM2_gw_NOI01, AREA, 'QIRRIG')

str_IWW_CESM2_gw_IRR02 = '/dodrio/scratch/projects/2022_200/project_output/cesm/yi_yao_IRRMIP/after_process/CESM2_gw/QIRRIG/CESM2_gw_IRR02_YEARLYQIRRIG_timmean_1901_2014.nc'
IWW_IRR_1901_2014_CESM2_gw_IRR02 = calcu_global_IWW(str_IWW_CESM2_gw_IRR02, AREA, 'QIRRIG')
str_IWW_CESM2_gw_NOI02 = '/dodrio/scratch/projects/2022_200/project_output/cesm/yi_yao_IRRMIP/after_process/CESM2_gw/QIRRIG/CESM2_gw_NOI02_YEARLYQIRRIG_timmean_1901_2014.nc'
IWW_NOI_1901_2014_CESM2_gw_IRR02 = calcu_global_IWW(str_IWW_CESM2_gw_NOI02, AREA, 'QIRRIG')

str_IWW_CESM2_gw_IRR03 = '/dodrio/scratch/projects/2022_200/project_output/cesm/yi_yao_IRRMIP/after_process/CESM2_gw/QIRRIG/CESM2_gw_IRR03_YEARLYQIRRIG_timmean_1901_2014.nc'
IWW_IRR_1901_2014_CESM2_gw_IRR03 = calcu_global_IWW(str_IWW_CESM2_gw_IRR03, AREA, 'QIRRIG')
str_IWW_CESM2_gw_NOI03 = '/dodrio/scratch/projects/2022_200/project_output/cesm/yi_yao_IRRMIP/after_process/CESM2_gw/QIRRIG/CESM2_gw_NOI03_YEARLYQIRRIG_timmean_1901_2014.nc'
IWW_NOI_1901_2014_CESM2_gw_IRR03 = calcu_global_IWW(str_IWW_CESM2_gw_NOI03, AREA, 'QIRRIG')

IWW_IRR_1901_2014_CESM2_gw = (IWW_IRR_1901_2014_CESM2_gw_IRR01 + IWW_IRR_1901_2014_CESM2_gw_IRR02 + IWW_IRR_1901_2014_CESM2_gw_IRR03)/3
IWW_NOI_1901_2014_CESM2_gw = (IWW_NOI_1901_2014_CESM2_gw_IRR01 + IWW_NOI_1901_2014_CESM2_gw_IRR02 + IWW_NOI_1901_2014_CESM2_gw_IRR03)/3

str_IWW_NorESM = '/dodrio/scratch/projects/2022_200/project_output/cesm/yi_yao_IRRMIP/after_process/NorESM/QIRRIG/NorESM_IRR_YEARLYQIRRIG_yearmean_1901_2014.nc'
IWW_IRR_1901_2014_NorESM = calcu_global_IWW(str_IWW_NorESM, AREA, 'QIRRIG')
str_IWW_NorESM_NOI = '/dodrio/scratch/projects/2022_200/project_output/cesm/yi_yao_IRRMIP/after_process/NorESM/QIRRIG/NorESM_NOI_YEARLYQIRRIG_yearmean_1901_2014.nc'
IWW_NOI_1901_2014_NorESM = calcu_global_IWW(str_IWW_NorESM_NOI, AREA, 'QIRRIG')

str_IWW_NorESM_IRR01 = '/dodrio/scratch/projects/2022_200/project_output/cesm/yi_yao_IRRMIP/after_process/NorESM/QIRRIG/NorESM_IRR01_YEARLYQIRRIG_yearmean_1901_2014.nc'
IWW_IRR_1901_2014_NorESM_IRR01 = calcu_global_IWW(str_IWW_NorESM_IRR01, AREA, 'QIRRIG')
str_IWW_NorESM_NOI01 = '/dodrio/scratch/projects/2022_200/project_output/cesm/yi_yao_IRRMIP/after_process/NorESM/QIRRIG/NorESM_NOI01_YEARLYQIRRIG_yearmean_1901_2014.nc'
IWW_NOI_1901_2014_NorESM_IRR01 = calcu_global_IWW(str_IWW_NorESM_NOI01, AREA, 'QIRRIG')

str_IWW_NorESM_IRR02 = '/dodrio/scratch/projects/2022_200/project_output/cesm/yi_yao_IRRMIP/after_process/NorESM/QIRRIG/NorESM_IRR02_YEARLYQIRRIG_yearmean_1901_2014.nc'
IWW_IRR_1901_2014_NorESM_IRR02 = calcu_global_IWW(str_IWW_NorESM_IRR02, AREA, 'QIRRIG')
str_IWW_NorESM_NOI02 = '/dodrio/scratch/projects/2022_200/project_output/cesm/yi_yao_IRRMIP/after_process/NorESM/QIRRIG/NorESM_NOI02_YEARLYQIRRIG_yearmean_1901_2014.nc'
IWW_NOI_1901_2014_NorESM_IRR02 = calcu_global_IWW(str_IWW_NorESM_NOI02, AREA, 'QIRRIG')

str_IWW_NorESM_IRR03 = '/dodrio/scratch/projects/2022_200/project_output/cesm/yi_yao_IRRMIP/after_process/NorESM/QIRRIG/NorESM_IRR03_YEARLYQIRRIG_yearmean_1901_2014.nc'
IWW_IRR_1901_2014_NorESM_IRR03 = calcu_global_IWW(str_IWW_NorESM_IRR03, AREA, 'QIRRIG')
str_IWW_NorESM_NOI03 = '/dodrio/scratch/projects/2022_200/project_output/cesm/yi_yao_IRRMIP/after_process/NorESM/QIRRIG/NorESM_NOI03_YEARLYQIRRIG_yearmean_1901_2014.nc'
IWW_NOI_1901_2014_NorESM_IRR03 = calcu_global_IWW(str_IWW_NorESM_NOI03, AREA, 'QIRRIG')

IWW_IRR_1901_2014_NorESM = (IWW_IRR_1901_2014_NorESM_IRR01 + IWW_IRR_1901_2014_NorESM_IRR02 + IWW_IRR_1901_2014_NorESM_IRR03)/3
IWW_NOI_1901_2014_NorESM = (IWW_IRR_1901_2014_NorESM_IRR01 + IWW_IRR_1901_2014_NorESM_IRR02 + IWW_IRR_1901_2014_NorESM_IRR03)/3

str_IWW_IPSL = '/dodrio/scratch/projects/2022_200/project_output/cesm/yi_yao_IRRMIP/IPSL-CM6/IRR01/after_processing/IRR01_1901_2014_irr_Day_Month.nc_YEARLY_0.9x1.25'
IWW_IRR_1901_2014_IPSL = calcu_global_IWW(str_IWW_IPSL, AREA, 'irr')

str_IWW_IPSL_IRR01 = '/dodrio/scratch/projects/2022_200/project_output/cesm/yi_yao_IRRMIP/IPSL-CM6/IRR01/after_processing/IRR01_1901_2014_irr_Day_Month.nc_YEARLY_0.9x1.25'
IWW_IRR_1901_2014_IPSL_IRR01 = calcu_global_IWW(str_IWW_IPSL_IRR01, AREA, 'irr')






str_IWW_CNRM = '/dodrio/scratch/projects/2022_200/project_output/cesm/yi_yao_IRRMIP/CNRM/CNRM-CM6-1_hist-irr_r1i1p1f2/after_processing/airrww_mon_CNRM-CM6-1_hist-irr_r1i1p1f2_gr_190101-201412.nc_yearmean_YEARLY_0.9x1.25'
IWW_IRR_1901_2014_CNRM = calcu_global_IWW(str_IWW_CNRM, AREA, 'airrww')
str_IWW_CNRM_NOI = '/dodrio/scratch/projects/2022_200/project_output/cesm/yi_yao_IRRMIP/CNRM/CNRM-CM6-1_hist-noirr_r1i1p1f2/after_processing/airrww_mon_CNRM-CM6-1_hist-noirr_r1i1p1f2_gr_190101-201412.nc_yearmean_YEARLY_0.9x1.25'
IWW_NOI_1901_2014_CNRM = calcu_global_IWW(str_IWW_CNRM_NOI, AREA, 'airrww')

str_IWW_CNRM_IRR01 = '/dodrio/scratch/projects/2022_200/project_output/cesm/yi_yao_IRRMIP/CNRM/CNRM-CM6-1_hist-irr_r1i1p1f2/after_processing/airrww_mon_CNRM-CM6-1_hist-irr_r1i1p1f2_gr_190101-201412.nc_yearmean_YEARLY_0.9x1.25'
IWW_IRR_1901_2014_CNRM_IRR01 = calcu_global_IWW(str_IWW_CNRM_IRR01, AREA, 'airrww')
str_IWW_CNRM_NOI01 = '/dodrio/scratch/projects/2022_200/project_output/cesm/yi_yao_IRRMIP/CNRM/CNRM-CM6-1_hist-noirr_r1i1p1f2/after_processing/airrww_mon_CNRM-CM6-1_hist-noirr_r1i1p1f2_gr_190101-201412.nc_yearmean_YEARLY_0.9x1.25'
IWW_NOI_1901_2014_CNRM_NOI01 = calcu_global_IWW(str_IWW_CNRM_NOI01, AREA, 'airrww')

# %%
str_IWW_E3SM = '/dodrio/scratch/projects/2022_200/project_output/cesm/yi_yao_IRRMIP/E3SM_cdo/Water_Energy/IRR_QIRRIG_REAL_yearmean_1901_2014.nc_0.9x1.25_YEARLY_yearmean'
IWW_IRR_1901_2014_E3SM = calcu_global_IWW(str_IWW_E3SM, AREA, 'QIRRIG_REAL')
str_IWW_E3SM_NOI = '/dodrio/scratch/projects/2022_200/project_output/cesm/yi_yao_IRRMIP/E3SM_cdo/Water_Energy/NOI_QIRRIG_REAL_yearmean_1901_2014.nc_0.9x1.25_YEARLY_yearmean'
IWW_NOI_1901_2014_E3SM = calcu_global_IWW(str_IWW_E3SM_NOI, AREA, 'QIRRIG_REAL')

str_IWW_E3SM_IRR01 = '/dodrio/scratch/projects/2022_200/project_output/cesm/yi_yao_IRRMIP/E3SM_cdo/IRR01/QIRRIG_REAL/IRR01_QIRRIG_REAL_yearmean_1901_2014.nc_0.9x1.25_YEARLY_yearmean'
IWW_IRR_1901_2014_E3SM_IRR01 = calcu_global_IWW(str_IWW_E3SM_IRR01, AREA, 'QIRRIG_REAL')
str_IWW_E3SM_IRR02 = '/dodrio/scratch/projects/2022_200/project_output/cesm/yi_yao_IRRMIP/E3SM_cdo/IRR02/QIRRIG_REAL/IRR02_QIRRIG_REAL_yearmean_1901_2014.nc_0.9x1.25_YEARLY_yearmean'
IWW_IRR_1901_2014_E3SM_IRR02 = calcu_global_IWW(str_IWW_E3SM_IRR02, AREA, 'QIRRIG_REAL')
str_IWW_E3SM_NOI01 = '/dodrio/scratch/projects/2022_200/project_output/cesm/yi_yao_IRRMIP/E3SM_cdo/NOI01/QIRRIG_REAL/NOI01_QIRRIG_REAL_yearmean_1901_2014.nc_0.9x1.25_YEARLY_yearmean'
IWW_IRR_1901_2014_E3SM_NOI01 = calcu_global_IWW(str_IWW_E3SM_NOI01, AREA, 'QIRRIG_REAL')
str_IWW_E3SM_NOI02 = '/dodrio/scratch/projects/2022_200/project_output/cesm/yi_yao_IRRMIP/E3SM_cdo/NOI02/QIRRIG_REAL/NOI02_QIRRIG_REAL_yearmean_1901_2014.nc_0.9x1.25_YEARLY_yearmean'
IWW_IRR_1901_2014_E3SM_NOI02 = calcu_global_IWW(str_IWW_E3SM_NOI02, AREA, 'QIRRIG_REAL')

IWW_IRR_1901_2014_E3SM = (IWW_IRR_1901_2014_E3SM_IRR01 + IWW_IRR_1901_2014_E3SM_IRR02)/2
IWW_NOI_1901_2014_E3SM = (IWW_IRR_1901_2014_E3SM_NOI01 + IWW_IRR_1901_2014_E3SM_NOI02)/2

# %%
IWW_IRR_1901_2014_CESM2_IRR01 = IWW_IRR_1901_2014_CESM2_IRR01[np.newaxis, :]
IWW_IRR_1901_2014_CESM2_IRR02 = IWW_IRR_1901_2014_CESM2_IRR02[np.newaxis, :]
IWW_IRR_1901_2014_CESM2_IRR03 = IWW_IRR_1901_2014_CESM2_IRR03[np.newaxis, :]

IWW_NOI_1901_2014_CESM2_IRR01 = IWW_NOI_1901_2014_CESM2_IRR01[np.newaxis, :]
IWW_NOI_1901_2014_CESM2_IRR02 = IWW_NOI_1901_2014_CESM2_IRR02[np.newaxis, :]
IWW_NOI_1901_2014_CESM2_IRR03 = IWW_NOI_1901_2014_CESM2_IRR03[np.newaxis, :]


IWW_IRR_1901_2014_CESM2_gw_IRR01 = IWW_IRR_1901_2014_CESM2_gw_IRR01[np.newaxis, :]
IWW_IRR_1901_2014_CESM2_gw_IRR02 = IWW_IRR_1901_2014_CESM2_gw_IRR02[np.newaxis, :]
IWW_IRR_1901_2014_CESM2_gw_IRR03 = IWW_IRR_1901_2014_CESM2_gw_IRR03[np.newaxis, :]

IWW_NOI_1901_2014_CESM2_gw_IRR01 = IWW_NOI_1901_2014_CESM2_gw_IRR01[np.newaxis, :]
IWW_NOI_1901_2014_CESM2_gw_IRR02 = IWW_NOI_1901_2014_CESM2_gw_IRR02[np.newaxis, :]
IWW_NOI_1901_2014_CESM2_gw_IRR03 = IWW_NOI_1901_2014_CESM2_gw_IRR03[np.newaxis, :]


IWW_IRR_1901_2014_NorESM_IRR01 = IWW_IRR_1901_2014_NorESM_IRR01[np.newaxis, :]
IWW_IRR_1901_2014_NorESM_IRR02 = IWW_IRR_1901_2014_NorESM_IRR02[np.newaxis, :]
IWW_IRR_1901_2014_NorESM_IRR03 = IWW_IRR_1901_2014_NorESM_IRR03[np.newaxis, :]

IWW_NOI_1901_2014_NorESM_IRR01 = IWW_NOI_1901_2014_NorESM_IRR01[np.newaxis, :]
IWW_NOI_1901_2014_NorESM_IRR02 = IWW_NOI_1901_2014_NorESM_IRR02[np.newaxis, :]
IWW_NOI_1901_2014_NorESM_IRR03 = IWW_NOI_1901_2014_NorESM_IRR03[np.newaxis, :]



IWW_IRR_1901_2014_IPSL_IRR01 = IWW_IRR_1901_2014_IPSL_IRR01[np.newaxis, :]





IWW_IRR_1901_2014_CNRM_IRR01 = IWW_IRR_1901_2014_CNRM_IRR01[np.newaxis, :]

IWW_NOI_1901_2014_CNRM_IRR01 = IWW_NOI_1901_2014_CNRM_NOI01[np.newaxis, :]

# %%
IWW_IRR_1901_2014_E3SM_IRR01 = IWW_IRR_1901_2014_E3SM_IRR01[np.newaxis, :]
IWW_IRR_1901_2014_E3SM_IRR02 = IWW_IRR_1901_2014_E3SM_IRR02[np.newaxis, :]

IWW_NOI_1901_2014_E3SM_IRR01 = IWW_IRR_1901_2014_E3SM_NOI01[np.newaxis, :]
IWW_NOI_1901_2014_E3SM_IRR02 = IWW_IRR_1901_2014_E3SM_NOI02[np.newaxis, :]

# %%
IWW_IRR_1901_2014_ens = np.concatenate(((IWW_IRR_1901_2014_CESM2_IRR01[:,:-1]+
                                        IWW_IRR_1901_2014_CESM2_IRR02[:,:-1]+
                                        IWW_IRR_1901_2014_CESM2_IRR03[:,:-1])/3,
                                        (IWW_IRR_1901_2014_CESM2_gw_IRR01[:,:-1]+IWW_IRR_1901_2014_CESM2_gw_IRR02[:,:-1]+IWW_IRR_1901_2014_CESM2_gw_IRR03[:,:-1])/3,
                                        (IWW_IRR_1901_2014_NorESM_IRR01[:,:-1]+IWW_IRR_1901_2014_NorESM_IRR02[:,:-1]+IWW_IRR_1901_2014_NorESM_IRR03[:,:-1])/3,
                                        IWW_IRR_1901_2014_IPSL_IRR01,
                                        (IWW_IRR_1901_2014_E3SM_IRR01[:,:-1]+IWW_IRR_1901_2014_E3SM_IRR02[:,:-1])/2,
                                        IWW_IRR_1901_2014_CNRM_IRR01),axis = 0)

IWW_NOI_1901_2014_ens = np.concatenate(((IWW_NOI_1901_2014_CESM2_IRR01[:,:-1]+IWW_NOI_1901_2014_CESM2_IRR02[:,:-1]+IWW_NOI_1901_2014_CESM2_IRR03[:,:-1])/3,
                                        (IWW_NOI_1901_2014_CESM2_gw_IRR01[:,:-1]+IWW_NOI_1901_2014_CESM2_gw_IRR02[:,:-1]+IWW_NOI_1901_2014_CESM2_gw_IRR03[:,:-1])/3,
                                        (IWW_NOI_1901_2014_NorESM_IRR01[:,:-1]+IWW_NOI_1901_2014_NorESM_IRR03[:,:-1])/2,
                                        (IWW_NOI_1901_2014_E3SM_IRR01[:,:-1]+IWW_NOI_1901_2014_E3SM_IRR02[:,:-1])/2,
                                        IWW_NOI_1901_2014_CNRM_IRR01),axis = 0)

IWW_IRR_1901_2014_25 = np.percentile(IWW_IRR_1901_2014_ens, 0, axis=0)
IWW_IRR_1901_2014_50 = np.percentile(IWW_IRR_1901_2014_ens, 50, axis=0)
IWW_IRR_1901_2014_75 = np.percentile(IWW_IRR_1901_2014_ens, 100, axis=0)

IWW_NOI_1901_2014_25 = np.percentile(IWW_NOI_1901_2014_ens, 0, axis=0)
IWW_NOI_1901_2014_50 = np.percentile(IWW_NOI_1901_2014_ens, 50, axis=0)
IWW_NOI_1901_2014_75 = np.percentile(IWW_NOI_1901_2014_ens, 100, axis=0)

# %%
IWW_IRR_1901_2014_CESM2_WNA = calcu_global_IWW_region(str_IWW_CESM2, AREA, 4, 'QIRRIG')
IWW_IRR_1901_2014_CESM2_CNA = calcu_global_IWW_region(str_IWW_CESM2, AREA, 5, 'QIRRIG')
IWW_IRR_1901_2014_CESM2_NCA = calcu_global_IWW_region(str_IWW_CESM2, AREA, 7, 'QIRRIG')
IWW_IRR_1901_2014_CESM2_MED = calcu_global_IWW_region(str_IWW_CESM2, AREA, 20, 'QIRRIG')
IWW_IRR_1901_2014_CESM2_WCA = calcu_global_IWW_region(str_IWW_CESM2, AREA, 33, 'QIRRIG')
IWW_IRR_1901_2014_CESM2_EAS = calcu_global_IWW_region(str_IWW_CESM2, AREA, 36, 'QIRRIG')
IWW_IRR_1901_2014_CESM2_SAS = calcu_global_IWW_region(str_IWW_CESM2, AREA, 38, 'QIRRIG')
IWW_IRR_1901_2014_CESM2_SEA = calcu_global_IWW_region(str_IWW_CESM2, AREA, 39, 'QIRRIG')

IWW_IRR_1901_2014_CESM2_gw_WNA = calcu_global_IWW_region(str_IWW_CESM2_gw, AREA, 4, 'QIRRIG')
IWW_IRR_1901_2014_CESM2_gw_CNA = calcu_global_IWW_region(str_IWW_CESM2_gw, AREA, 5, 'QIRRIG')
IWW_IRR_1901_2014_CESM2_gw_NCA = calcu_global_IWW_region(str_IWW_CESM2_gw, AREA, 7, 'QIRRIG')
IWW_IRR_1901_2014_CESM2_gw_MED = calcu_global_IWW_region(str_IWW_CESM2_gw, AREA, 20, 'QIRRIG')
IWW_IRR_1901_2014_CESM2_gw_WCA = calcu_global_IWW_region(str_IWW_CESM2_gw, AREA, 33, 'QIRRIG')
IWW_IRR_1901_2014_CESM2_gw_EAS = calcu_global_IWW_region(str_IWW_CESM2_gw, AREA, 36, 'QIRRIG')
IWW_IRR_1901_2014_CESM2_gw_SAS = calcu_global_IWW_region(str_IWW_CESM2_gw, AREA, 38, 'QIRRIG')
IWW_IRR_1901_2014_CESM2_gw_SEA = calcu_global_IWW_region(str_IWW_CESM2_gw, AREA, 39, 'QIRRIG')

IWW_IRR_1901_2014_NorESM_WNA = calcu_global_IWW_region(str_IWW_NorESM, AREA, 4, 'QIRRIG')
IWW_IRR_1901_2014_NorESM_CNA = calcu_global_IWW_region(str_IWW_NorESM, AREA, 5, 'QIRRIG')
IWW_IRR_1901_2014_NorESM_NCA = calcu_global_IWW_region(str_IWW_NorESM, AREA, 7, 'QIRRIG')
IWW_IRR_1901_2014_NorESM_MED = calcu_global_IWW_region(str_IWW_NorESM, AREA, 20, 'QIRRIG')
IWW_IRR_1901_2014_NorESM_WCA = calcu_global_IWW_region(str_IWW_NorESM, AREA, 33, 'QIRRIG')
IWW_IRR_1901_2014_NorESM_EAS = calcu_global_IWW_region(str_IWW_NorESM, AREA, 36, 'QIRRIG')
IWW_IRR_1901_2014_NorESM_SAS = calcu_global_IWW_region(str_IWW_NorESM, AREA, 38, 'QIRRIG')
IWW_IRR_1901_2014_NorESM_SEA = calcu_global_IWW_region(str_IWW_NorESM, AREA, 39, 'QIRRIG')

IWW_IRR_1901_2014_E3SM_WNA = calcu_global_IWW_region(str_IWW_E3SM, AREA, 4, 'QIRRIG_REAL')
IWW_IRR_1901_2014_E3SM_CNA = calcu_global_IWW_region(str_IWW_E3SM, AREA, 5, 'QIRRIG_REAL')
IWW_IRR_1901_2014_E3SM_NCA = calcu_global_IWW_region(str_IWW_E3SM, AREA, 7, 'QIRRIG_REAL')
IWW_IRR_1901_2014_E3SM_MED = calcu_global_IWW_region(str_IWW_E3SM, AREA, 20, 'QIRRIG_REAL')
IWW_IRR_1901_2014_E3SM_WCA = calcu_global_IWW_region(str_IWW_E3SM, AREA, 33, 'QIRRIG_REAL')
IWW_IRR_1901_2014_E3SM_EAS = calcu_global_IWW_region(str_IWW_E3SM, AREA, 36, 'QIRRIG_REAL')
IWW_IRR_1901_2014_E3SM_SAS = calcu_global_IWW_region(str_IWW_E3SM, AREA, 38, 'QIRRIG_REAL')
IWW_IRR_1901_2014_E3SM_SEA = calcu_global_IWW_region(str_IWW_E3SM, AREA, 39, 'QIRRIG_REAL')

IWW_IRR_1901_2014_CNRM_WNA = calcu_global_IWW_region(str_IWW_CNRM, AREA, 4, 'airrww')
IWW_IRR_1901_2014_CNRM_CNA = calcu_global_IWW_region(str_IWW_CNRM, AREA, 5, 'airrww')
IWW_IRR_1901_2014_CNRM_NCA = calcu_global_IWW_region(str_IWW_CNRM, AREA, 7, 'airrww')
IWW_IRR_1901_2014_CNRM_MED = calcu_global_IWW_region(str_IWW_CNRM, AREA, 20, 'airrww')
IWW_IRR_1901_2014_CNRM_WCA = calcu_global_IWW_region(str_IWW_CNRM, AREA, 33, 'airrww')
IWW_IRR_1901_2014_CNRM_EAS = calcu_global_IWW_region(str_IWW_CNRM, AREA, 36, 'airrww')
IWW_IRR_1901_2014_CNRM_SAS = calcu_global_IWW_region(str_IWW_CNRM, AREA, 38, 'airrww')
IWW_IRR_1901_2014_CNRM_SEA = calcu_global_IWW_region(str_IWW_CNRM, AREA, 39, 'airrww')

IWW_IRR_1901_2014_IPSL_WNA = calcu_global_IWW_region(str_IWW_IPSL, AREA, 4, 'irr')
IWW_IRR_1901_2014_IPSL_CNA = calcu_global_IWW_region(str_IWW_IPSL, AREA, 5, 'irr')
IWW_IRR_1901_2014_IPSL_NCA = calcu_global_IWW_region(str_IWW_IPSL, AREA, 7, 'irr')
IWW_IRR_1901_2014_IPSL_MED = calcu_global_IWW_region(str_IWW_IPSL, AREA, 20, 'irr')
IWW_IRR_1901_2014_IPSL_WCA = calcu_global_IWW_region(str_IWW_IPSL, AREA, 33, 'irr')
IWW_IRR_1901_2014_IPSL_EAS = calcu_global_IWW_region(str_IWW_IPSL, AREA, 36, 'irr')
IWW_IRR_1901_2014_IPSL_SAS = calcu_global_IWW_region(str_IWW_IPSL, AREA, 38, 'irr')
IWW_IRR_1901_2014_IPSL_SEA = calcu_global_IWW_region(str_IWW_IPSL, AREA, 39, 'irr')

# IWW_IRR_1901_2014_MIROC_WNA = calcu_global_IWW_region(str_IWW_MIROC, AREA, 4, 'irrac')
# IWW_IRR_1901_2014_MIROC_CNA = calcu_global_IWW_region(str_IWW_MIROC, AREA, 5, 'irrac')
# IWW_IRR_1901_2014_MIROC_NCA = calcu_global_IWW_region(str_IWW_MIROC, AREA, 7, 'irrac')
# IWW_IRR_1901_2014_MIROC_MED = calcu_global_IWW_region(str_IWW_MIROC, AREA, 20, 'irrac')
# IWW_IRR_1901_2014_MIROC_WCA = calcu_global_IWW_region(str_IWW_MIROC, AREA, 33, 'irrac')
# IWW_IRR_1901_2014_MIROC_EAS = calcu_global_IWW_region(str_IWW_MIROC, AREA, 36, 'irrac')
# IWW_IRR_1901_2014_MIROC_SAS = calcu_global_IWW_region(str_IWW_MIROC, AREA, 38, 'irrac')
# IWW_IRR_1901_2014_MIROC_SEA = calcu_global_IWW_region(str_IWW_MIROC, AREA, 39, 'irrac')

# %%
def plot_fill_between(ax, index, data1, data2, title, title1, label, color, ylabel, xlabel, marker):
    ax.text(-0.05, 1.05, index, color='dimgrey', fontsize=12, transform=ax.transAxes, weight='bold')
    # ax.step(range(1901, 2015), data, label = label, color = color, linewidth = 1, marker = marker, markersize=1.2)
    ax.fill_between(range(1901, 2015), data1, data2, label = label, color = color, linewidth = 1, alpha=0.8)
    plt.title(title, loc='right')
    plt.title(title1, loc='left')
    plt.ylabel(ylabel, fontsize = 14)
    plt.xlabel(xlabel, fontsize = 14)
    plt.yticks(fontsize = 12)
    plt.xticks(fontsize=12)
    
    
def plot_fill_between_all(ax, index, data1, data2, data3, data4, data5, data6, data7, data8, data9, ylabel, ylim_max):
    plot_fill_between(ax, '', data1 + data2 + data3 + data4 + data5 + data6 + data7 + data8, data9, '', '', 'Other', 'chocolate', ylabel, 'year', '^')
    plot_fill_between(ax, '', data1 + data2 + data3 + data4 + data5 + data6 + data7, data1 + data2 + data3 + data4 + data5 + data6 + data7 + data8, '', '', 'WNA', 'b', ylabel, 'year', '^')
    plot_fill_between(ax, '', data1 + data2 + data3 + data4 + data5 + data6, data1 + data2 + data3 + data4 + data5 + data6 + data7, '', '', 'CNA', 'c', ylabel, 'year', '^')
    plot_fill_between(ax, '', data1 + data2 + data3 + data4 + data5, data1 + data2 + data3 + data4 + data5 + data6, '', '', 'NCA', 'g', ylabel, 'year', '^')
    plot_fill_between(ax, '', data1 + data2 + data3 + data4, data1 + data2 + data3 + data4 + data5, '', '', 'MED', 'm', ylabel, 'year', '^')
    plot_fill_between(ax, '', data1 + data2 + data3, data1 + data2 + data3 + data4, '', '', 'WCA', 'r', ylabel, 'year', '^')
    plot_fill_between(ax, '', data1 + data2, data1 + data2 + data3, '', '', 'EAS', 'y', ylabel, 'year', '^')
    plot_fill_between(ax, '', data1, data1 + data2, '', '', 'SAS', 'orange', ylabel, 'year', '^')
    plot_fill_between(ax, index, 0, data1, '', '', 'SEA', 'pink', ylabel, 'year', '^')
    ax1.set_ylim(0,ylim_max)
    ax1.set_xlim(1901,2014)
    
def plot_line(ax, index, data, title, title1, label, color, ylabel, xlabel, marker):
    ax.text(-0.05, 1.05, index, color='dimgrey', fontsize=12, transform=ax.transAxes, weight='bold')
    # ax.step(range(1901, 2015), data, label = label, color = color, linewidth = 1, marker = marker, markersize=1.2)
    ax.plot(range(1901, 2015), data, label = label, color = color, linewidth = 2, markersize=1.2, alpha=0.8)
    plt.title(title, loc='right')
    plt.title(title1, loc='left')
    plt.ylabel(ylabel, fontsize = 14)
    plt.xlabel(xlabel, fontsize = 14)
    plt.yticks(fontsize = 12)
    plt.xticks(fontsize=12)
    plt.xlim(1901,2015)
    plt.legend(loc='upper left')

fig = plt.figure(figsize=(20, 8),dpi=300)
fig.subplots_adjust(hspace=0.3, wspace=0.3, left = 0.05, right = 0.95, top = 0.95, bottom = 0.05)

ax1 = plt.subplot(241, frameon=True)
ax1.spines["top"].set_visible(True)
ax1.spines["right"].set_visible(True)
plot_fill_between_all(ax1, 'a', global_irri_land_SEA[:] / 1000000, global_irri_land_SAS[:] / 1000000, global_irri_land_EAS[:] / 1000000, global_irri_land_WCA[:] / 1000000, global_irri_land_MED[:] / 1000000, global_irri_land_NCA[:] / 1000000, global_irri_land_CNA[:] / 1000000, global_irri_land_WNA[:] / 1000000, global_irri_land[:] / 1000000, 'AEI ($\mathregular{10^6}$ $\mathregular{km^2}$)', 3)    
plt.grid(linestyle = '--')
plt.legend(loc = 'upper left')

# ax1 = plt.subplot2grid((2, 3), (0, 1), colspan = 2)
ax1 = plt.subplot(242, frameon=True)
ax1.text(-0.05, 1.05, 'b', color='dimgrey', fontsize=12, transform=ax1.transAxes, weight='bold')

plot_line(ax1, '', IWW_IRR_1901_2014_50, '', '', 'tranirr', 'b', '', 'year', '^')
plot_line(ax1, '', IWW_NOI_1901_2014_50, '', '', '1901irr', 'r', '', 'year', '>')
plt.ylabel('IWW ($\mathregular{km^3/yr}$)', fontsize = 14)
ax1.fill_between(range(1901, 2015), IWW_IRR_1901_2014_25, IWW_IRR_1901_2014_75, color = 'b', linewidth = 2, alpha=0.2)
ax1.fill_between(range(1901, 2015), IWW_NOI_1901_2014_25, IWW_NOI_1901_2014_75, color = 'r', linewidth = 2, alpha=0.2)
ax1.set_ylim(0,4500)
plt.grid(linestyle = '--')

ax1 = plt.subplot(243, frameon=True)
# plt.ylabel('Irrigation water($\mathregular{km^3}$)', fontsize = 14)
plot_fill_between_all(ax1, 'c CESM2', IWW_IRR_1901_2014_CESM2_SEA[:-1], IWW_IRR_1901_2014_CESM2_SAS[:-1], IWW_IRR_1901_2014_CESM2_EAS[:-1], IWW_IRR_1901_2014_CESM2_WCA[:-1], IWW_IRR_1901_2014_CESM2_MED[:-1], IWW_IRR_1901_2014_CESM2_NCA[:-1], IWW_IRR_1901_2014_CESM2_CNA[:-1], IWW_IRR_1901_2014_CESM2_WNA[:-1], IWW_IRR_1901_2014_CESM2[:-1], '', 1100)    
plt.grid(linestyle = '--')
plt.ylabel('IWW ($\mathregular{km^3/yr}$)', fontsize = 14)
ax1.set_ylim(0,4500)
# plt.ylabel('Irrigation water \n withdrawal ($\mathregular{km^3/yr}$)', fontsize = 14)
ax1 = plt.subplot(244, frameon=True)
# plt.ylabel('Irrigation water \n withdrawal ($\mathregular{km^3/yr}$)', fontsize = 14)
plot_fill_between_all(ax1, 'd CESM2_gw', IWW_IRR_1901_2014_CESM2_gw_SEA[:-1], IWW_IRR_1901_2014_CESM2_gw_SAS[:-1], IWW_IRR_1901_2014_CESM2_gw_EAS[:-1], IWW_IRR_1901_2014_CESM2_gw_WCA[:-1], IWW_IRR_1901_2014_CESM2_gw_MED[:-1], IWW_IRR_1901_2014_CESM2_gw_NCA[:-1], IWW_IRR_1901_2014_CESM2_gw_CNA[:-1], IWW_IRR_1901_2014_CESM2_gw_WNA[:-1], IWW_IRR_1901_2014_CESM2_gw[:-1], '', 1100)    
plt.grid(linestyle = '--')
plt.ylabel('IWW ($\mathregular{km^3/yr}$)', fontsize = 14)
ax1.set_ylim(0,4500)
# plt.ylabel('Irrigation water \n withdrawal ($\mathregular{km^3/yr}$)', fontsize = 14)
ax1 = plt.subplot(245, frameon=True)
# plt.ylabel('Irrigation water \n withdrawal ($\mathregular{km^3/yr}$)', fontsize = 14)
plot_fill_between_all(ax1, 'e NorESM', IWW_IRR_1901_2014_NorESM_SEA[:-1], IWW_IRR_1901_2014_NorESM_SAS[:-1], IWW_IRR_1901_2014_NorESM_EAS[:-1], IWW_IRR_1901_2014_NorESM_WCA[:-1], IWW_IRR_1901_2014_NorESM_MED[:-1], IWW_IRR_1901_2014_NorESM_NCA[:-1], IWW_IRR_1901_2014_NorESM_CNA[:-1], IWW_IRR_1901_2014_NorESM_WNA[:-1], IWW_IRR_1901_2014_NorESM[:-1], '', 1100)    
plt.grid(linestyle = '--')
plt.ylabel('IWW ($\mathregular{km^3/yr}$)', fontsize = 14)
ax1.set_ylim(0,4500)
ax1 = plt.subplot(246, frameon=True)
# plt.ylabel('Irrigation water \n withdrawal ($\mathregular{km^3/yr}$)', fontsize = 14)
plot_fill_between_all(ax1, 'f E3SM', IWW_IRR_1901_2014_E3SM_SEA[:-1], IWW_IRR_1901_2014_E3SM_SAS[:-1], IWW_IRR_1901_2014_E3SM_EAS[:-1], IWW_IRR_1901_2014_E3SM_WCA[:-1], IWW_IRR_1901_2014_E3SM_MED[:-1], IWW_IRR_1901_2014_E3SM_NCA[:-1], IWW_IRR_1901_2014_E3SM_CNA[:-1], IWW_IRR_1901_2014_E3SM_WNA[:-1], IWW_IRR_1901_2014_E3SM[:-1], '', 1100)    
plt.grid(linestyle = '--')
plt.ylabel('IWW ($\mathregular{km^3/yr}$)', fontsize = 14)
ax1.set_ylim(0,4500)
# plt.ylabel('Irrigation water \n withdrawal ($\mathregular{km^3/yr}$)', fontsize = 14)
ax1 = plt.subplot(247, frameon=True)

# plot_fill_between_all(ax1, 'c MIROC', IWW_IRR_1901_2014_MIROC_SEA, IWW_IRR_1901_2014_MIROC_SAS, IWW_IRR_1901_2014_MIROC_EAS, IWW_IRR_1901_2014_MIROC_WCA, IWW_IRR_1901_2014_MIROC_MED, IWW_IRR_1901_2014_MIROC_NCA, IWW_IRR_1901_2014_MIROC_CNA, IWW_IRR_1901_2014_MIROC_WNA, IWW_IRR_1901_2014_MIROC, 'Irrigation water($\mathregular{km^3}$)', 1100)    
# plt.grid(linestyle = '--')
# ax1.set_ylim(0,2000)
# ax1 = plt.subplot(338, frameon=True)

plot_fill_between_all(ax1, 'g CNRM-CM6', IWW_IRR_1901_2014_CNRM_SEA, IWW_IRR_1901_2014_CNRM_SAS, IWW_IRR_1901_2014_CNRM_EAS, IWW_IRR_1901_2014_CNRM_WCA, IWW_IRR_1901_2014_CNRM_MED, IWW_IRR_1901_2014_CNRM_NCA, IWW_IRR_1901_2014_CNRM_CNA, IWW_IRR_1901_2014_CNRM_WNA, IWW_IRR_1901_2014_CNRM, '', 1100)    
plt.grid(linestyle = '--')
plt.ylabel('IWW ($\mathregular{km^3/yr}$)', fontsize = 14)
ax1.set_ylim(0,4500)
# plt.ylabel('Irrigation water \n withdrawal ($\mathregular{km^3/yr}$)', fontsize = 14)
ax1 = plt.subplot(248, frameon=True)

plot_fill_between_all(ax1, 'h IPSL-CM6', IWW_IRR_1901_2014_IPSL_SEA, IWW_IRR_1901_2014_IPSL_SAS, IWW_IRR_1901_2014_IPSL_EAS, IWW_IRR_1901_2014_IPSL_WCA, IWW_IRR_1901_2014_IPSL_MED, IWW_IRR_1901_2014_IPSL_NCA, IWW_IRR_1901_2014_IPSL_CNA, IWW_IRR_1901_2014_IPSL_WNA, IWW_IRR_1901_2014_IPSL, '', 1100)    
plt.grid(linestyle = '--')
plt.ylabel('IWW ($\mathregular{km^3/yr}$)', fontsize = 14)
ax1.set_ylim(0,4500)
# plt.ylabel('Irrigation water \n withdrawal ($\mathregular{km^3/yr}$)', fontsize = 14)
